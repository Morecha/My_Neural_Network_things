# %% [markdown]
# **Post Test - Self-Organizing Maps**

# %% [markdown]
# *Self-organizing maps*(SOM), atau yang disebut juga dengan
# topology-preserving maps, adalah sebuah algoritma klasterisasi (clustering)
# sehingga termasuk pada algoritma unsupervised learning.

# %% [markdown]
# #Kode (Jangan diubah)
# Fungsi *self-organizing maps*

# %%
import numpy as np

def som(X, lrate, b, max_epoch, n_cluster):
    centroids = np.random.uniform(size=(n_cluster, len(X[0])))
    epoch = 0
    labels = []
    while epoch < max_epoch:
        for x in X:
            d = [sum((w - x) ** 2) for w in centroids]
            min = np.argmin(d)
            centroids[min] += lrate * (x - centroids[min])
        lrate *= b
        epoch += 1

    for x in X:
        d = [sum((w - x) ** 2) for w in centroids]
        min = np.argmin(d)
        labels.append(min)
    return centroids, labels

def draw(X, target, centroids):
    colors = 'rgbcmyk'
    for x, label in zip(X, target):
        plt.plot(x[0], x[1], colors[label] + '.')
    plt.plot(centroids[:, 0], centroids[:, 1], 'kx')

# %% [markdown]
# #Soal

# %% [markdown]
# Gunakan dataset "Mall_Customers.csv" yang telah dilampirkan

# %% [markdown]
# Terdapat data Mall Segentation yang berisikan data CustomerID, Gender, Age, Annual Income (k$), Spending Score (1-100). Pada data tersebut, akan dilakukan klasterisasi menjadi 3 klaster dengan:
# 1. learning rate=0.1, b=0.2, dan max_epoc=3

# %% [markdown]
# ### a) Load data

# %%
import pandas as pd

data = pd.read_csv('Mall_Customers.csv')
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ### b) Preprocess

# %%
data['Gender'] = data['Gender'].map({'Female': 0, 'Male': 1})
# data['Gender'].unique()   #for what is this?

data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %% [markdown]
# ### c) Klasterisasi

# %%
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Data yang digunakan untuk klasterisasi adalah fitur Annual Income (k$)	Spending Score (1-100)
X = data[['Annual Income (k$)', 'Spending Score (1-100)'] ].values # diisi praktikan
print('Data:\n', X)

centroids, labels = som(X, lrate=0.6 , b=0.5 , max_epoch=100 , n_cluster=3) # isi sesuai dengan perintah
print('centroid terbaru:\n',centroids)

# Hitung Silhouette score
silhouette = silhouette_score(X, labels)
print('Silhouette score:', silhouette)
draw(X, labels, centroids)
# Out:
# Data:
#  [[ 15  39]
#  [ 15  81]
#  [ 16   6]
#  [ 16  77]
#  [ 17  40]
#  [ 17  76]
#  [ 18   6]
#  [ 18  94]
#  [ 19   3]
#  [ 19  72]
#  [ 19  14]
#  [ 19  99]
#  [ 20  15]
#  [ 20  77]
#  [ 20  13]
#  [ 20  79]
#  [ 21  35]
#  [ 21  66]
#  [ 23  29]
#  [ 23  98]
#  [ 24  35]
#  [ 24  73]
#  [ 25   5]
#  [ 25  73]
#  [ 28  14]
#  [ 28  82]
#  [ 28  32]
#  [ 28  61]
#  [ 29  31]
#  [ 29  87]
#  [ 30   4]
#  [ 30  73]
#  [ 33   4]
#  [ 33  92]
#  [ 33  14]
#  [ 33  81]
#  [ 34  17]
#  [ 34  73]
#  [ 37  26]
#  [ 37  75]
#  [ 38  35]
#  [ 38  92]
#  [ 39  36]
#  [ 39  61]
#  [ 39  28]
#  [ 39  65]
#  [ 40  55]
#  [ 40  47]
#  [ 40  42]
#  [ 40  42]
#  [ 42  52]
#  [ 42  60]
#  [ 43  54]
#  [ 43  60]
#  [ 43  45]
#  [ 43  41]
#  [ 44  50]
#  [ 44  46]
#  [ 46  51]
#  [ 46  46]
#  [ 46  56]
#  [ 46  55]
#  [ 47  52]
#  [ 47  59]
#  [ 48  51]
#  [ 48  59]
#  [ 48  50]
#  [ 48  48]
#  [ 48  59]
#  [ 48  47]
#  [ 49  55]
#  [ 49  42]
#  [ 50  49]
#  [ 50  56]
#  [ 54  47]
#  [ 54  54]
#  [ 54  53]
#  [ 54  48]
#  [ 54  52]
#  [ 54  42]
#  [ 54  51]
#  [ 54  55]
#  [ 54  41]
#  [ 54  44]
#  [ 54  57]
#  [ 54  46]
#  [ 57  58]
#  [ 57  55]
#  [ 58  60]
#  [ 58  46]
#  [ 59  55]
#  [ 59  41]
#  [ 60  49]
#  [ 60  40]
#  [ 60  42]
#  [ 60  52]
#  [ 60  47]
#  [ 60  50]
#  [ 61  42]
#  [ 61  49]
#  [ 62  41]
#  [ 62  48]
#  [ 62  59]
#  [ 62  55]
#  [ 62  56]
#  [ 62  42]
#  [ 63  50]
#  [ 63  46]
#  [ 63  43]
#  [ 63  48]
#  [ 63  52]
#  [ 63  54]
#  [ 64  42]
#  [ 64  46]
#  [ 65  48]
#  [ 65  50]
#  [ 65  43]
#  [ 65  59]
#  [ 67  43]
#  [ 67  57]
#  [ 67  56]
#  [ 67  40]
#  [ 69  58]
#  [ 69  91]
#  [ 70  29]
#  [ 70  77]
#  [ 71  35]
#  [ 71  95]
#  [ 71  11]
#  [ 71  75]
#  [ 71   9]
#  [ 71  75]
#  [ 72  34]
#  [ 72  71]
#  [ 73   5]
#  [ 73  88]
#  [ 73   7]
#  [ 73  73]
#  [ 74  10]
#  [ 74  72]
#  [ 75   5]
#  [ 75  93]
#  [ 76  40]
#  [ 76  87]
#  [ 77  12]
#  [ 77  97]
#  [ 77  36]
#  [ 77  74]
#  [ 78  22]
#  [ 78  90]
#  [ 78  17]
#  [ 78  88]
#  [ 78  20]
#  [ 78  76]
#  [ 78  16]
#  [ 78  89]
#  [ 78   1]
#  [ 78  78]
#  [ 78   1]
#  [ 78  73]
#  [ 79  35]
#  [ 79  83]
#  [ 81   5]
#  [ 81  93]
#  [ 85  26]
#  [ 85  75]
#  [ 86  20]
#  [ 86  95]
#  [ 87  27]
#  [ 87  63]
#  [ 87  13]
#  [ 87  75]
#  [ 87  10]
#  [ 87  92]
#  [ 88  13]
#  [ 88  86]
#  [ 88  15]
#  [ 88  69]
#  [ 93  14]
#  [ 93  90]
#  [ 97  32]
#  [ 97  86]
#  [ 98  15]
#  [ 98  88]
#  [ 99  39]
#  [ 99  97]
#  [101  24]
#  [101  68]
#  [103  17]
#  [103  85]
#  [103  23]
#  [103  69]
#  [113   8]
#  [113  91]
#  [120  16]
#  [120  79]
#  [126  28]
#  [126  74]
#  [137  18]
#  [137  83]]
# centroid terbaru:
#  [[120.16963635  21.47200486]
#  [ 57.84333113  34.10528791]
#  [ 66.71737575  76.34976933]]
# Silhouette score: 0.2928755896067793

# %% [markdown]
# Perbandingan Klasterisasi

# %%
#hasil perbandingan
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Data yang digunakan untuk klasterisasi adalah fitur Annual Income (k$)	Spending Score (1-100)
X = data[['Annual Income (k$)', 'Spending Score (1-100)'] ].values # diisi praktikan
print('Data:\n', X)

centroids, labels = som(X, lrate=0.5 , b=0.8 , max_epoch=100 , n_cluster=3) #cari parameter untuk mendapatkan hasil klasterisasi yang lebih baik
print('centroid terbaru:\n',centroids)

# Hitung Silhouette score
silhouette = silhouette_score(X, labels)
print('Silhouette score:', silhouette)
draw(X, labels, centroids)
# Out:
# Data:
#  [[ 15  39]
#  [ 15  81]
#  [ 16   6]
#  [ 16  77]
#  [ 17  40]
#  [ 17  76]
#  [ 18   6]
#  [ 18  94]
#  [ 19   3]
#  [ 19  72]
#  [ 19  14]
#  [ 19  99]
#  [ 20  15]
#  [ 20  77]
#  [ 20  13]
#  [ 20  79]
#  [ 21  35]
#  [ 21  66]
#  [ 23  29]
#  [ 23  98]
#  [ 24  35]
#  [ 24  73]
#  [ 25   5]
#  [ 25  73]
#  [ 28  14]
#  [ 28  82]
#  [ 28  32]
#  [ 28  61]
#  [ 29  31]
#  [ 29  87]
#  [ 30   4]
#  [ 30  73]
#  [ 33   4]
#  [ 33  92]
#  [ 33  14]
#  [ 33  81]
#  [ 34  17]
#  [ 34  73]
#  [ 37  26]
#  [ 37  75]
#  [ 38  35]
#  [ 38  92]
#  [ 39  36]
#  [ 39  61]
#  [ 39  28]
#  [ 39  65]
#  [ 40  55]
#  [ 40  47]
#  [ 40  42]
#  [ 40  42]
#  [ 42  52]
#  [ 42  60]
#  [ 43  54]
#  [ 43  60]
#  [ 43  45]
#  [ 43  41]
#  [ 44  50]
#  [ 44  46]
#  [ 46  51]
#  [ 46  46]
#  [ 46  56]
#  [ 46  55]
#  [ 47  52]
#  [ 47  59]
#  [ 48  51]
#  [ 48  59]
#  [ 48  50]
#  [ 48  48]
#  [ 48  59]
#  [ 48  47]
#  [ 49  55]
#  [ 49  42]
#  [ 50  49]
#  [ 50  56]
#  [ 54  47]
#  [ 54  54]
#  [ 54  53]
#  [ 54  48]
#  [ 54  52]
#  [ 54  42]
#  [ 54  51]
#  [ 54  55]
#  [ 54  41]
#  [ 54  44]
#  [ 54  57]
#  [ 54  46]
#  [ 57  58]
#  [ 57  55]
#  [ 58  60]
#  [ 58  46]
#  [ 59  55]
#  [ 59  41]
#  [ 60  49]
#  [ 60  40]
#  [ 60  42]
#  [ 60  52]
#  [ 60  47]
#  [ 60  50]
#  [ 61  42]
#  [ 61  49]
#  [ 62  41]
#  [ 62  48]
#  [ 62  59]
#  [ 62  55]
#  [ 62  56]
#  [ 62  42]
#  [ 63  50]
#  [ 63  46]
#  [ 63  43]
#  [ 63  48]
#  [ 63  52]
#  [ 63  54]
#  [ 64  42]
#  [ 64  46]
#  [ 65  48]
#  [ 65  50]
#  [ 65  43]
#  [ 65  59]
#  [ 67  43]
#  [ 67  57]
#  [ 67  56]
#  [ 67  40]
#  [ 69  58]
#  [ 69  91]
#  [ 70  29]
#  [ 70  77]
#  [ 71  35]
#  [ 71  95]
#  [ 71  11]
#  [ 71  75]
#  [ 71   9]
#  [ 71  75]
#  [ 72  34]
#  [ 72  71]
#  [ 73   5]
#  [ 73  88]
#  [ 73   7]
#  [ 73  73]
#  [ 74  10]
#  [ 74  72]
#  [ 75   5]
#  [ 75  93]
#  [ 76  40]
#  [ 76  87]
#  [ 77  12]
#  [ 77  97]
#  [ 77  36]
#  [ 77  74]
#  [ 78  22]
#  [ 78  90]
#  [ 78  17]
#  [ 78  88]
#  [ 78  20]
#  [ 78  76]
#  [ 78  16]
#  [ 78  89]
#  [ 78   1]
#  [ 78  78]
#  [ 78   1]
#  [ 78  73]
#  [ 79  35]
#  [ 79  83]
#  [ 81   5]
#  [ 81  93]
#  [ 85  26]
#  [ 85  75]
#  [ 86  20]
#  [ 86  95]
#  [ 87  27]
#  [ 87  63]
#  [ 87  13]
#  [ 87  75]
#  [ 87  10]
#  [ 87  92]
#  [ 88  13]
#  [ 88  86]
#  [ 88  15]
#  [ 88  69]
#  [ 93  14]
#  [ 93  90]
#  [ 97  32]
#  [ 97  86]
#  [ 98  15]
#  [ 98  88]
#  [ 99  39]
#  [ 99  97]
#  [101  24]
#  [101  68]
#  [103  17]
#  [103  85]
#  [103  23]
#  [103  69]
#  [113   8]
#  [113  91]
#  [120  16]
#  [120  79]
#  [126  28]
#  [126  74]
#  [137  18]
#  [137  83]]
# centroid terbaru:
#  [[82.04341949 81.66697966]
#  [91.43910071 17.86224809]
#  [45.4636123  49.3744179 ]]
# Silhouette score: 0.46761358158775435

# %% [markdown]
#  Kita tidak menggunakan akurasi untuk menilai kinerja clustering, melainkan silhouette score. Silhouette score adalah metrik yang digunakan untuk menghitung seberapa baik pengelompokan/clustering. Nilainya berkisar antara -1 hingga 1. dengan detail sebagai berikut.
#
# -  1: cluster berjauhan satu sama lain dan dapat dibedakan dengan jelas.
#
# -  0 : Berarti cluster bersifat indifferent, atau dapat dikatakan jarak antar cluster tidak signifikan.
#
# -  -1: Berarti cluster dikelompokkan dengan cara yang salah.
#
# <br>
#
# **Pertanyaan**
#
# 1. Carilah learning rate, b, dan max epoch yang sesuai dan menghasilkan hasil clustering yang cukup baik!
#
# 2. Bandingkan hasil yang didapatkan dan jelaskan apa pengaruh learning rate, b, dan max epox yang di masukkan!

# %% [markdown]
# **Jawaban :**
#
# 1. learning rate=0.5 , b=0.8 , max_epoch=100. hasil ini menunjukkan hasil sulhouette yang cukup baik yaitu bernilai positif yaitu 0.468... dimana hasil ini menunjukkan bahwa data berkumpul dengan kelompoknya dan memiliki rentan yang cukup jauh dari kelas lainnya.
#
# 2. pada hasil pertama (alpha=0.6 , beta=0.5 , max epoch=100), menunjukkan lebih buruk dari yang ke-2. dimana hal ini menunjukkan sifat beta sendiri yang cukup baik bila nilainya cukup tinggi. untuk beta sendiri mempengaruhi alpha setiap epochnya dalam menjalankan learning rate. dimana beta yang terlalu besar akan mengakibatkan learning rate turun terlalu cepat yang mengakibatkan konvergensi lambat yang dapat membuat algoritma membutuhkan lebih banyak epoch untuk mencapai konvergensi. sedangankan sebaliknya beta yang kecil sendiri dapat mempengaruhi alpha yang membuatnya learning rate sangat lambat dan dapat menyebabkan model konvergensi cukup cepat ataupun dapat berdampak overfitting pada proses pelatihannya.
